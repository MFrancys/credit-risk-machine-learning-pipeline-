# %% [markdown]
# # 3.1.0. EDA: Identify Features with High Correlation
#
# ### Methodology
#
# This step in exploratory data analysis (EDA) aims to identify and exclude features from the dataset that exhibit high correlation, specifically those with a correlation coefficient greater than 0.80. This process helps reduce multicollinearity, which can adversely affect the performance of many machine learning models by making the model parameters difficult to interpret and unstable.
#
# Approach:
# - Calculate the Pearson correlation matrix for all numeric features in the dataset.
# - Identify Highly Correlated Pairs: Using the function identify_high_correlation(data, threshold=0.9), identify all pairs of features whose absolute correlation exceeds the threshold of 0.80. This step effectively pinpoints potentially redundant features or have similar information content.
# - Feature Selection: Review the list of highly correlated feature pairs. Decide which feature from each pair to retain based on:
#     Importance in Modeling: Prefer features that are known to have a strong impact or relevance based on domain knowledge or previous modeling experiences.
#     Data Quality: Retain features with fewer missing values or less noise.
#     Business Relevance: Consider business understanding or input on which features are more interpretable or valuable for decision-making processes.
#
# ### Conclusion
# - Initial Feature Count: Begin with an initial set of 262 features.
# - Feature Exclusion: After applying the correlation threshold, identify 109 features that are highly correlated with others. From each correlated pair or group, choose to drop the feature that is less significant from a business or data quality perspective, retaining 153 features for further analysis.

# %%
import yaml
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from pathlib import Path
pd.set_option("display.max_rows", None)
pd.set_option('display.max_colwidth', None)

# %%
def identify_high_correlation(data: pd.DataFrame, threshold: float = 0.8) -> pd.DataFrame:
    """
    Identifies pairs of columns in a DataFrame with correlation higher than a specified threshold.
    
    Parameters:
    - data (pd.DataFrame): The input DataFrame containing numeric columns.
    - threshold (float): The correlation coefficient above which a pair is considered highly correlated.

    Returns:
    - pd.DataFrame: A DataFrame listing pairs of highly correlated features, their correlation values, and their indices.
    """
    
    corr_matrix = data.corr()
    
    correlated_features = []
    
    for i in range(len(corr_matrix.columns)):
        for j in range(i+1, len(corr_matrix.columns)):
            if abs(corr_matrix.iloc[i, j]) > threshold:  # Only consider absolute coefficient value
                correlated_features.append((corr_matrix.columns[i], corr_matrix.columns[j], corr_matrix.iloc[i, j]))

    correlated_df = pd.DataFrame(correlated_features, columns=['Feature 1', 'Feature 2', 'Correlation'])
    
    return correlated_df

# %% [markdown]
# ### 1. Load Data

# %%
with open("config.yaml", "r") as f:
    config = yaml.safe_load(f)
    
numeric_features = config["raw_features"]["numerical"]
features = numeric_features
target = config["main"]["target"]
data_train_path = Path.cwd().parent / config["main"]["data_train_path"]

# %%
features = features + [
    'credit_reports__age_max_credito_de_habilitacion_o_avio',
    'credit_reports__age_max_hipoteca',
    'credit_reports__age_max_pagos_fijos',
    'credit_reports__age_max_por_determinar',
    'credit_reports__age_max_revolvente',
    'credit_reports__age_max_sin_limite_preestablecido',
    'credit_reports__age_median_credito_de_habilitacion_o_avio',
    'credit_reports__age_median_hipoteca',
    'credit_reports__age_median_pagos_fijos',
    'credit_reports__age_median_por_determinar',
    'credit_reports__age_median_revolvente',
    'credit_reports__age_median_sin_limite_preestablecido',
    'credit_reports__age_std_credito_de_habilitacion_o_avio',
    'credit_reports__age_std_hipoteca',
    'credit_reports__age_std_pagos_fijos',
    'credit_reports__age_std_por_determinar',
    'credit_reports__age_std_revolvente',
    'credit_reports__age_std_sin_limite_preestablecido',
    'credit_reports__balance_due_median_credito_de_habilitacion_o_avio',
    'credit_reports__balance_due_median_hipoteca',
    'credit_reports__balance_due_median_pagos_fijos',
    'credit_reports__balance_due_median_por_determinar',
    'credit_reports__balance_due_median_revolvente',
    'credit_reports__balance_due_median_sin_limite_preestablecido',
    'credit_reports__balance_due_ratio_max_credito_de_habilitacion_o_avio',
    'credit_reports__balance_due_ratio_max_hipoteca',
    'credit_reports__balance_due_ratio_max_pagos_fijos',
    'credit_reports__balance_due_ratio_max_por_determinar',
    'credit_reports__balance_due_ratio_max_revolvente',
    'credit_reports__balance_due_ratio_max_sin_limite_preestablecido',
    'credit_reports__balance_due_ratio_median_credito_de_habilitacion_o_avio',
    'credit_reports__balance_due_ratio_median_hipoteca',
    'credit_reports__balance_due_ratio_median_pagos_fijos',
    'credit_reports__balance_due_ratio_median_por_determinar',
    'credit_reports__balance_due_ratio_median_revolvente',
    'credit_reports__balance_due_ratio_median_sin_limite_preestablecido',
    'credit_reports__balance_due_ratio_std_credito_de_habilitacion_o_avio',
    'credit_reports__balance_due_ratio_std_hipoteca',
    'credit_reports__balance_due_ratio_std_pagos_fijos',
    'credit_reports__balance_due_ratio_std_por_determinar',
    'credit_reports__balance_due_ratio_std_revolvente',
    'credit_reports__balance_due_ratio_std_sin_limite_preestablecido',
    'credit_reports__balance_due_std_credito_de_habilitacion_o_avio',
    'credit_reports__balance_due_std_hipoteca',
    'credit_reports__balance_due_std_pagos_fijos',
    'credit_reports__balance_due_std_por_determinar',
    'credit_reports__balance_due_std_revolvente',
    'credit_reports__balance_due_std_sin_limite_preestablecido',
    'credit_reports__balance_due_sum_credito_de_habilitacion_o_avio',
    'credit_reports__balance_due_sum_hipoteca',
    'credit_reports__balance_due_sum_pagos_fijos',
    'credit_reports__balance_due_sum_por_determinar',
    'credit_reports__balance_due_sum_revolvente',
    'credit_reports__balance_due_sum_sin_limite_preestablecido',
    'credit_reports__balance_due_worst_delay_max_credito_de_habilitacion_o_avio',
    'credit_reports__balance_due_worst_delay_max_hipoteca',
    'credit_reports__balance_due_worst_delay_max_pagos_fijos',
    'credit_reports__balance_due_worst_delay_max_por_determinar',
    'credit_reports__balance_due_worst_delay_max_revolvente',
    'credit_reports__balance_due_worst_delay_max_sin_limite_preestablecido',
    'credit_reports__balance_due_worst_delay_median_credito_de_habilitacion_o_avio',
    'credit_reports__balance_due_worst_delay_median_hipoteca',
    'credit_reports__balance_due_worst_delay_median_pagos_fijos',
    'credit_reports__balance_due_worst_delay_median_por_determinar',
    'credit_reports__balance_due_worst_delay_median_revolvente',
    'credit_reports__balance_due_worst_delay_median_sin_limite_preestablecido',
    'credit_reports__balance_due_worst_delay_ratio_max_credito_de_habilitacion_o_avio',
    'credit_reports__balance_due_worst_delay_ratio_max_hipoteca',
    'credit_reports__balance_due_worst_delay_ratio_max_pagos_fijos',
    'credit_reports__balance_due_worst_delay_ratio_max_por_determinar',
    'credit_reports__balance_due_worst_delay_ratio_max_revolvente',
    'credit_reports__balance_due_worst_delay_ratio_max_sin_limite_preestablecido',
    'credit_reports__balance_due_worst_delay_ratio_median_credito_de_habilitacion_o_avio',
    'credit_reports__balance_due_worst_delay_ratio_median_hipoteca',
    'credit_reports__balance_due_worst_delay_ratio_median_pagos_fijos',
    'credit_reports__balance_due_worst_delay_ratio_median_por_determinar',
    'credit_reports__balance_due_worst_delay_ratio_median_revolvente',
    'credit_reports__balance_due_worst_delay_ratio_median_sin_limite_preestablecido',
    'credit_reports__balance_due_worst_delay_ratio_std_credito_de_habilitacion_o_avio',
    'credit_reports__balance_due_worst_delay_ratio_std_hipoteca',
    'credit_reports__balance_due_worst_delay_ratio_std_pagos_fijos',
    'credit_reports__balance_due_worst_delay_ratio_std_por_determinar',
    'credit_reports__balance_due_worst_delay_ratio_std_revolvente',
    'credit_reports__balance_due_worst_delay_ratio_std_sin_limite_preestablecido',
    'credit_reports__balance_due_worst_delay_std_credito_de_habilitacion_o_avio',
    'credit_reports__balance_due_worst_delay_std_hipoteca',
    'credit_reports__balance_due_worst_delay_std_pagos_fijos',
    'credit_reports__balance_due_worst_delay_std_por_determinar',
    'credit_reports__balance_due_worst_delay_std_revolvente',
    'credit_reports__balance_due_worst_delay_std_sin_limite_preestablecido',
    'credit_reports__business_type_nunique_credito_de_habilitacion_o_avio',
    'credit_reports__business_type_nunique_hipoteca',
    'credit_reports__business_type_nunique_pagos_fijos',
    'credit_reports__business_type_nunique_por_determinar',
    'credit_reports__business_type_nunique_revolvente',
    'credit_reports__business_type_nunique_sin_limite_preestablecido',
    'credit_reports__cdc_inquiry_id_count_credito_de_habilitacion_o_avio',
    'credit_reports__cdc_inquiry_id_count_hipoteca',
    'credit_reports__cdc_inquiry_id_count_pagos_fijos',
    'credit_reports__cdc_inquiry_id_count_por_determinar',
    'credit_reports__cdc_inquiry_id_count_revolvente',
    'credit_reports__cdc_inquiry_id_count_sin_limite_preestablecido',
    'credit_reports__credit_limit_median_credito_de_habilitacion_o_avio',
    'credit_reports__credit_limit_median_hipoteca',
    'credit_reports__credit_limit_median_pagos_fijos',
    'credit_reports__credit_limit_median_por_determinar',
    'credit_reports__credit_limit_median_revolvente',
    'credit_reports__credit_limit_median_sin_limite_preestablecido',
    'credit_reports__credit_limit_std_credito_de_habilitacion_o_avio',
    'credit_reports__credit_limit_std_hipoteca',
    'credit_reports__credit_limit_std_pagos_fijos',
    'credit_reports__credit_limit_std_por_determinar',
    'credit_reports__credit_limit_std_revolvente',
    'credit_reports__credit_limit_std_sin_limite_preestablecido',
    'credit_reports__credit_limit_sum_credito_de_habilitacion_o_avio',
    'credit_reports__credit_limit_sum_hipoteca',
    'credit_reports__credit_limit_sum_pagos_fijos',
    'credit_reports__credit_limit_sum_por_determinar',
    'credit_reports__credit_limit_sum_revolvente',
    'credit_reports__credit_limit_sum_sin_limite_preestablecido',
    'credit_reports__credit_type_nunique_credito_de_habilitacion_o_avio',
    'credit_reports__credit_type_nunique_hipoteca',
    'credit_reports__credit_type_nunique_pagos_fijos',
    'credit_reports__credit_type_nunique_por_determinar',
    'credit_reports__credit_type_nunique_revolvente',
    'credit_reports__credit_type_nunique_sin_limite_preestablecido',
    'credit_reports__current_balance_median_credito_de_habilitacion_o_avio',
    'credit_reports__current_balance_median_hipoteca',
    'credit_reports__current_balance_median_pagos_fijos',
    'credit_reports__current_balance_median_por_determinar',
    'credit_reports__current_balance_median_revolvente',
    'credit_reports__current_balance_median_sin_limite_preestablecido',
    'credit_reports__current_balance_std_credito_de_habilitacion_o_avio',
    'credit_reports__current_balance_std_hipoteca',
    'credit_reports__current_balance_std_pagos_fijos',
    'credit_reports__current_balance_std_por_determinar',
    'credit_reports__current_balance_std_revolvente',
    'credit_reports__current_balance_std_sin_limite_preestablecido',
    'credit_reports__current_balance_sum_credito_de_habilitacion_o_avio',
    'credit_reports__current_balance_sum_hipoteca',
    'credit_reports__current_balance_sum_pagos_fijos',
    'credit_reports__current_balance_sum_por_determinar',
    'credit_reports__current_balance_sum_revolvente',
    'credit_reports__current_balance_sum_sin_limite_preestablecido',
    'credit_reports__debt_ratio_max_credito_de_habilitacion_o_avio',
    'credit_reports__debt_ratio_max_hipoteca',
    'credit_reports__debt_ratio_max_pagos_fijos',
    'credit_reports__debt_ratio_max_por_determinar',
    'credit_reports__debt_ratio_max_revolvente',
    'credit_reports__debt_ratio_max_sin_limite_preestablecido',
    'credit_reports__debt_ratio_median_credito_de_habilitacion_o_avio',
    'credit_reports__debt_ratio_median_hipoteca',
    'credit_reports__debt_ratio_median_pagos_fijos',
    'credit_reports__debt_ratio_median_por_determinar',
    'credit_reports__debt_ratio_median_revolvente',
    'credit_reports__debt_ratio_median_sin_limite_preestablecido',
    'credit_reports__debt_ratio_std_credito_de_habilitacion_o_avio',
    'credit_reports__debt_ratio_std_hipoteca',
    'credit_reports__debt_ratio_std_pagos_fijos',
    'credit_reports__debt_ratio_std_por_determinar',
    'credit_reports__debt_ratio_std_revolvente',
    'credit_reports__debt_ratio_std_sin_limite_preestablecido',
    'credit_reports__has_delayed_payments_sum_credito_de_habilitacion_o_avio',
    'credit_reports__has_delayed_payments_sum_hipoteca',
    'credit_reports__has_delayed_payments_sum_pagos_fijos',
    'credit_reports__has_delayed_payments_sum_por_determinar',
    'credit_reports__has_delayed_payments_sum_revolvente',
    'credit_reports__has_delayed_payments_sum_sin_limite_preestablecido',
    'credit_reports__is_individual_responsibility_sum_credito_de_habilitacion_o_avio',
    'credit_reports__is_individual_responsibility_sum_hipoteca',
    'credit_reports__is_individual_responsibility_sum_pagos_fijos',
    'credit_reports__is_individual_responsibility_sum_por_determinar',
    'credit_reports__is_individual_responsibility_sum_revolvente',
    'credit_reports__is_individual_responsibility_sum_sin_limite_preestablecido',
    'credit_reports__max_credit_median_credito_de_habilitacion_o_avio',
    'credit_reports__max_credit_median_hipoteca',
    'credit_reports__max_credit_median_pagos_fijos',
    'credit_reports__max_credit_median_por_determinar',
    'credit_reports__max_credit_median_revolvente',
    'credit_reports__max_credit_median_sin_limite_preestablecido',
    'credit_reports__max_credit_std_credito_de_habilitacion_o_avio',
    'credit_reports__max_credit_std_hipoteca',
    'credit_reports__max_credit_std_pagos_fijos',
    'credit_reports__max_credit_std_por_determinar',
    'credit_reports__max_credit_std_revolvente',
    'credit_reports__max_credit_std_sin_limite_preestablecido',
    'credit_reports__max_credit_sum_credito_de_habilitacion_o_avio',
    'credit_reports__max_credit_sum_hipoteca',
    'credit_reports__max_credit_sum_pagos_fijos',
    'credit_reports__max_credit_sum_por_determinar',
    'credit_reports__max_credit_sum_revolvente',
    'credit_reports__max_credit_sum_sin_limite_preestablecido',
    'credit_reports__payment_amount_sum_credito_de_habilitacion_o_avio',
    'credit_reports__payment_amount_sum_hipoteca',
    'credit_reports__payment_amount_sum_pagos_fijos',
    'credit_reports__payment_amount_sum_por_determinar',
    'credit_reports__payment_amount_sum_revolvente',
    'credit_reports__payment_amount_sum_sin_limite_preestablecido',
    'credit_reports__severity_delayed_payments_max_credito_de_habilitacion_o_avio',
    'credit_reports__severity_delayed_payments_max_hipoteca',
    'credit_reports__severity_delayed_payments_max_pagos_fijos',
    'credit_reports__severity_delayed_payments_max_por_determinar',
    'credit_reports__severity_delayed_payments_max_revolvente',
    'credit_reports__severity_delayed_payments_max_sin_limite_preestablecido',
    'credit_reports__severity_delayed_payments_median_credito_de_habilitacion_o_avio',
    'credit_reports__severity_delayed_payments_median_hipoteca',
    'credit_reports__severity_delayed_payments_median_pagos_fijos',
    'credit_reports__severity_delayed_payments_median_por_determinar',
    'credit_reports__severity_delayed_payments_median_revolvente',
    'credit_reports__severity_delayed_payments_median_sin_limite_preestablecido',
    'credit_reports__severity_delayed_payments_std_credito_de_habilitacion_o_avio',
    'credit_reports__severity_delayed_payments_std_hipoteca',
    'credit_reports__severity_delayed_payments_std_pagos_fijos',
    'credit_reports__severity_delayed_payments_std_por_determinar',
    'credit_reports__severity_delayed_payments_std_revolvente',
    'credit_reports__severity_delayed_payments_std_sin_limite_preestablecido',
]
train_df = pd.read_pickle(data_train_path)[features]
train_df.shape
# Out:
# (9479, 259)

# %%
high_corr_features = identify_high_correlation(train_df[features], threshold=0.90)
high_corr_features.sort_values("Correlation", ascending=False)
# Out:
#                                                                                Feature 1  \
# 228     credit_reports__balance_due_worst_delay_ratio_max_credito_de_habilitacion_o_avio
# 246  credit_reports__balance_due_worst_delay_ratio_median_credito_de_habilitacion_o_avio
# 245  credit_reports__balance_due_worst_delay_ratio_median_credito_de_habilitacion_o_avio
# 227     credit_reports__balance_due_worst_delay_ratio_max_credito_de_habilitacion_o_avio
# 283                      credit_reports__credit_limit_sum_credito_de_habilitacion_o_avio
# 103                 credit_reports__balance_due_ratio_max_credito_de_habilitacion_o_avio
# 270                   credit_reports__credit_limit_median_credito_de_habilitacion_o_avio
# 271                   credit_reports__credit_limit_median_credito_de_habilitacion_o_avio
# 282                      credit_reports__credit_limit_sum_credito_de_habilitacion_o_avio
# 104                 credit_reports__balance_due_ratio_max_credito_de_habilitacion_o_avio
# 133              credit_reports__balance_due_ratio_median_credito_de_habilitacion_o_avio
# 132              credit_reports__balance_due_ratio_median_credito_de_habilitacion_o_avio
# 130              credit_reports__balance_due_ratio_median_credito_de_habilitacion_o_avio
# 224     credit_reports__balance_due_worst_delay_ratio_max_credito_de_habilitacion_o_avio
# 223     credit_reports__balance_due_worst_delay_ratio_max_credito_de_habilitacion_o_avio
# 242  credit_reports__balance_due_worst_delay_ratio_median_credito_de_habilitacion_o_avio
# 241  credit_reports__balance_due_worst_delay_ratio_median_credito_de_habilitacion_o_avio
# 101                 credit_reports__balance_due_ratio_max_credito_de_habilitacion_o_avio
# 102                 credit_reports__balance_due_ratio_max_credito_de_habilitacion_o_avio
# 131              credit_reports__balance_due_ratio_median_credito_de_habilitacion_o_avio
# 226     credit_reports__balance_due_worst_delay_ratio_max_credito_de_habilitacion_o_avio
# 182           credit_reports__balance_due_worst_delay_max_credito_de_habilitacion_o_avio
# 244  credit_reports__balance_due_worst_delay_ratio_median_credito_de_habilitacion_o_avio
# 202        credit_reports__balance_due_worst_delay_median_credito_de_habilitacion_o_avio
# 183           credit_reports__balance_due_worst_delay_max_credito_de_habilitacion_o_avio
# 203        credit_reports__balance_due_worst_delay_median_credito_de_habilitacion_o_avio
# 219     credit_reports__balance_due_worst_delay_ratio_max_credito_de_habilitacion_o_avio
# 237  credit_reports__balance_due_worst_delay_ratio_median_credito_de_habilitacion_o_avio
# 238  credit_reports__balance_due_worst_delay_ratio_median_credito_de_habilitacion_o_avio
# 220     credit_reports__balance_due_worst_delay_ratio_max_credito_de_habilitacion_o_avio
# 274                   credit_reports__credit_limit_median_credito_de_habilitacion_o_avio
# 287                      credit_reports__credit_limit_sum_credito_de_habilitacion_o_avio
# 286                      credit_reports__credit_limit_sum_credito_de_habilitacion_o_avio
# 275                   credit_reports__credit_limit_median_credito_de_habilitacion_o_avio
# 139              credit_reports__balance_due_ratio_median_credito_de_habilitacion_o_avio
# 321                     credit_reports__debt_ratio_median_credito_de_habilitacion_o_avio
# 314                        credit_reports__debt_ratio_max_credito_de_habilitacion_o_avio
# 110                 credit_reports__balance_due_ratio_max_credito_de_habilitacion_o_avio
# 168                       credit_reports__balance_due_sum_credito_de_habilitacion_o_avio
# 84                     credit_reports__balance_due_median_credito_de_habilitacion_o_avio
# 295                credit_reports__current_balance_median_credito_de_habilitacion_o_avio
# 305                   credit_reports__current_balance_sum_credito_de_habilitacion_o_avio
# 76                     credit_reports__balance_due_median_credito_de_habilitacion_o_avio
# 77                     credit_reports__balance_due_median_credito_de_habilitacion_o_avio
# 160                       credit_reports__balance_due_sum_credito_de_habilitacion_o_avio
# 161                       credit_reports__balance_due_sum_credito_de_habilitacion_o_avio
# 210        credit_reports__balance_due_worst_delay_median_credito_de_habilitacion_o_avio
# 221     credit_reports__balance_due_worst_delay_ratio_max_credito_de_habilitacion_o_avio
# 190           credit_reports__balance_due_worst_delay_max_credito_de_habilitacion_o_avio
# 222     credit_reports__balance_due_worst_delay_ratio_max_credito_de_habilitacion_o_avio
# 239  credit_reports__balance_due_worst_delay_ratio_median_credito_de_habilitacion_o_avio
# 240  credit_reports__balance_due_worst_delay_ratio_median_credito_de_habilitacion_o_avio
# 208        credit_reports__balance_due_worst_delay_median_credito_de_habilitacion_o_avio
# 313                        credit_reports__debt_ratio_max_credito_de_habilitacion_o_avio
# 99                  credit_reports__balance_due_ratio_max_credito_de_habilitacion_o_avio
# 100                 credit_reports__balance_due_ratio_max_credito_de_habilitacion_o_avio
# 138              credit_reports__balance_due_ratio_median_credito_de_habilitacion_o_avio
# 128              credit_reports__balance_due_ratio_median_credito_de_habilitacion_o_avio
# 209        credit_reports__balance_due_worst_delay_median_credito_de_habilitacion_o_avio
# 188           credit_reports__balance_due_worst_delay_max_credito_de_habilitacion_o_avio
# 109                 credit_reports__balance_due_ratio_max_credito_de_habilitacion_o_avio
# 189           credit_reports__balance_due_worst_delay_max_credito_de_habilitacion_o_avio
# 129              credit_reports__balance_due_ratio_median_credito_de_habilitacion_o_avio
# 320                     credit_reports__debt_ratio_median_credito_de_habilitacion_o_avio
# 322                     credit_reports__debt_ratio_median_credito_de_habilitacion_o_avio
# 140              credit_reports__balance_due_ratio_median_credito_de_habilitacion_o_avio
# 141              credit_reports__balance_due_ratio_median_credito_de_habilitacion_o_avio
# 315                        credit_reports__debt_ratio_max_credito_de_habilitacion_o_avio
# 316                        credit_reports__debt_ratio_max_credito_de_habilitacion_o_avio
# 191           credit_reports__balance_due_worst_delay_max_credito_de_habilitacion_o_avio
# 324              credit_reports__has_delayed_payments_sum_credito_de_habilitacion_o_avio
# 325              credit_reports__has_delayed_payments_sum_credito_de_habilitacion_o_avio
# 326              credit_reports__has_delayed_payments_sum_credito_de_habilitacion_o_avio
# 112                 credit_reports__balance_due_ratio_max_credito_de_habilitacion_o_avio
# 111                 credit_reports__balance_due_ratio_max_credito_de_habilitacion_o_avio
# 211        credit_reports__balance_due_worst_delay_median_credito_de_habilitacion_o_avio
# 323                     credit_reports__debt_ratio_median_credito_de_habilitacion_o_avio
# 97                  credit_reports__balance_due_ratio_max_credito_de_habilitacion_o_avio
# 108                 credit_reports__balance_due_ratio_max_credito_de_habilitacion_o_avio
# 164                       credit_reports__balance_due_sum_credito_de_habilitacion_o_avio
# 165                       credit_reports__balance_due_sum_credito_de_habilitacion_o_avio
# 181           credit_reports__balance_due_worst_delay_max_credito_de_habilitacion_o_avio
# 107                 credit_reports__balance_due_ratio_max_credito_de_habilitacion_o_avio
# 137              credit_reports__balance_due_ratio_median_credito_de_habilitacion_o_avio
# 81                     credit_reports__balance_due_median_credito_de_habilitacion_o_avio
# 73                     credit_reports__balance_due_median_credito_de_habilitacion_o_avio
# 292                credit_reports__current_balance_median_credito_de_habilitacion_o_avio
# 334         credit_reports__severity_delayed_payments_max_credito_de_habilitacion_o_avio
# 267                   credit_reports__credit_limit_median_credito_de_habilitacion_o_avio
# 266                       credit_reports__cdc_inquiry_id_count_sin_limite_preestablecido
# 218     credit_reports__balance_due_worst_delay_ratio_max_credito_de_habilitacion_o_avio
# 136              credit_reports__balance_due_ratio_median_credito_de_habilitacion_o_avio
# 312                        credit_reports__debt_ratio_max_credito_de_habilitacion_o_avio
# 80                     credit_reports__balance_due_median_credito_de_habilitacion_o_avio
# 284                      credit_reports__credit_limit_sum_credito_de_habilitacion_o_avio
# 272                   credit_reports__credit_limit_median_credito_de_habilitacion_o_avio
# 273                   credit_reports__credit_limit_median_credito_de_habilitacion_o_avio
# 285                      credit_reports__credit_limit_sum_credito_de_habilitacion_o_avio
# 243  credit_reports__balance_due_worst_delay_ratio_median_credito_de_habilitacion_o_avio
# 225     credit_reports__balance_due_worst_delay_ratio_max_credito_de_habilitacion_o_avio
# 332                    credit_reports__payment_amount_sum_credito_de_habilitacion_o_avio
# 333                    credit_reports__payment_amount_sum_credito_de_habilitacion_o_avio
# 185           credit_reports__balance_due_worst_delay_max_credito_de_habilitacion_o_avio
# 184           credit_reports__balance_due_worst_delay_max_credito_de_habilitacion_o_avio
# 162                       credit_reports__balance_due_sum_credito_de_habilitacion_o_avio
# 163                       credit_reports__balance_due_sum_credito_de_habilitacion_o_avio
# 205        credit_reports__balance_due_worst_delay_median_credito_de_habilitacion_o_avio
# 204        credit_reports__balance_due_worst_delay_median_credito_de_habilitacion_o_avio
# 79                     credit_reports__balance_due_median_credito_de_habilitacion_o_avio
# 78                     credit_reports__balance_due_median_credito_de_habilitacion_o_avio
# 281                      credit_reports__credit_limit_sum_credito_de_habilitacion_o_avio
# 269                   credit_reports__credit_limit_median_credito_de_habilitacion_o_avio
# 268                   credit_reports__credit_limit_median_credito_de_habilitacion_o_avio
# 280                      credit_reports__credit_limit_sum_credito_de_habilitacion_o_avio
# 296                credit_reports__current_balance_median_credito_de_habilitacion_o_avio
# 169                       credit_reports__balance_due_sum_credito_de_habilitacion_o_avio
# 306                   credit_reports__current_balance_sum_credito_de_habilitacion_o_avio
# 85                     credit_reports__balance_due_median_credito_de_habilitacion_o_avio
# 74                     credit_reports__balance_due_median_credito_de_habilitacion_o_avio
# 159                       credit_reports__balance_due_sum_credito_de_habilitacion_o_avio
# 158                       credit_reports__balance_due_sum_credito_de_habilitacion_o_avio
# 75                     credit_reports__balance_due_median_credito_de_habilitacion_o_avio
# 186           credit_reports__balance_due_worst_delay_max_credito_de_habilitacion_o_avio
# 207        credit_reports__balance_due_worst_delay_median_credito_de_habilitacion_o_avio
# 206        credit_reports__balance_due_worst_delay_median_credito_de_habilitacion_o_avio
# 187           credit_reports__balance_due_worst_delay_max_credito_de_habilitacion_o_avio
# 213        credit_reports__balance_due_worst_delay_median_credito_de_habilitacion_o_avio
# 212        credit_reports__balance_due_worst_delay_median_credito_de_habilitacion_o_avio
# 193           credit_reports__balance_due_worst_delay_max_credito_de_habilitacion_o_avio
# 192           credit_reports__balance_due_worst_delay_max_credito_de_habilitacion_o_avio
# 308                   credit_reports__current_balance_sum_credito_de_habilitacion_o_avio
# 298                credit_reports__current_balance_median_credito_de_habilitacion_o_avio
# 307                   credit_reports__current_balance_sum_credito_de_habilitacion_o_avio
# 170                       credit_reports__balance_due_sum_credito_de_habilitacion_o_avio
# 171                       credit_reports__balance_due_sum_credito_de_habilitacion_o_avio
# 297                credit_reports__current_balance_median_credito_de_habilitacion_o_avio
# 86                     credit_reports__balance_due_median_credito_de_habilitacion_o_avio
# 87                     credit_reports__balance_due_median_credito_de_habilitacion_o_avio
# 167                       credit_reports__balance_due_sum_credito_de_habilitacion_o_avio
# 303                   credit_reports__current_balance_sum_credito_de_habilitacion_o_avio
# 294                credit_reports__current_balance_median_credito_de_habilitacion_o_avio
# 71                     credit_reports__balance_due_median_credito_de_habilitacion_o_avio
# 72                     credit_reports__balance_due_median_credito_de_habilitacion_o_avio
# 293                credit_reports__current_balance_median_credito_de_habilitacion_o_avio
# 82                     credit_reports__balance_due_median_credito_de_habilitacion_o_avio
# 83                     credit_reports__balance_due_median_credito_de_habilitacion_o_avio
# 304                   credit_reports__current_balance_sum_credito_de_habilitacion_o_avio
# 166                       credit_reports__balance_due_sum_credito_de_habilitacion_o_avio
# 134              credit_reports__balance_due_ratio_median_credito_de_habilitacion_o_avio
# 98                  credit_reports__balance_due_ratio_max_credito_de_habilitacion_o_avio
# 105                 credit_reports__balance_due_ratio_max_credito_de_habilitacion_o_avio
# 106                 credit_reports__balance_due_ratio_max_credito_de_habilitacion_o_avio
# 135              credit_reports__balance_due_ratio_median_credito_de_habilitacion_o_avio
# 127              credit_reports__balance_due_ratio_median_credito_de_habilitacion_o_avio
# 152                                     credit_reports__balance_due_ratio_std_revolvente
# 124                                     credit_reports__balance_due_ratio_max_revolvente
# 16                                                        credit_reports__debt_ratio_max
# 12                                                        credit_reports__debt_ratio_max
# 145                                  credit_reports__balance_due_ratio_median_revolvente
# 5                                                         credit_reports__max_credit_sum
# 177                                       credit_reports__balance_due_sum_por_determinar
# 57                                credit_reports__age_max_credito_de_habilitacion_o_avio
# 8                                                         credit_reports__debt_ratio_max
# 26                                                 credit_reports__balance_due_ratio_max
# 30                                                 credit_reports__balance_due_ratio_max
# 335                               credit_reports__severity_delayed_payments_max_hipoteca
# 92                                     credit_reports__balance_due_median_por_determinar
# 116                                    credit_reports__balance_due_ratio_max_pagos_fijos
# 150                                     credit_reports__balance_due_ratio_std_revolvente
# 250                         credit_reports__balance_due_worst_delay_ratio_std_revolvente
# 122                                     credit_reports__balance_due_ratio_max_revolvente
# 234                         credit_reports__balance_due_worst_delay_ratio_max_revolvente
# 14                                                        credit_reports__debt_ratio_max
# 28                                                 credit_reports__balance_due_ratio_max
# 154                                       credit_reports__balance_due_std_por_determinar
# 146                                  credit_reports__balance_due_ratio_median_revolvente
# 247                      credit_reports__balance_due_worst_delay_ratio_median_revolvente
# 255                                       credit_reports__business_type_nunique_hipoteca
# 310                                   credit_reports__current_balance_sum_por_determinar
# 328                     credit_reports__max_credit_median_credito_de_habilitacion_o_avio
# 125                                     credit_reports__balance_due_ratio_max_revolvente
# 121                                     credit_reports__balance_due_ratio_max_revolvente
# 319                                            credit_reports__debt_ratio_max_revolvente
# 151                                     credit_reports__balance_due_ratio_std_revolvente
# 17                                                        credit_reports__debt_ratio_max
# 13                                                        credit_reports__debt_ratio_max
# 233                         credit_reports__balance_due_worst_delay_ratio_max_revolvente
# 31                                                 credit_reports__balance_due_ratio_max
# 27                                                 credit_reports__balance_due_ratio_max
# 229                           credit_reports__balance_due_worst_delay_ratio_max_hipoteca
# 175                                       credit_reports__balance_due_sum_por_determinar
# 123                                     credit_reports__balance_due_ratio_max_revolvente
# 249                         credit_reports__balance_due_worst_delay_ratio_std_revolvente
# 15                                                        credit_reports__debt_ratio_max
# 58                                                      credit_reports__age_max_hipoteca
# 6                                                    credit_reports__current_balance_sum
# 113                                       credit_reports__balance_due_ratio_max_hipoteca
# 235                         credit_reports__balance_due_worst_delay_ratio_max_revolvente
# 149                                     credit_reports__balance_due_ratio_std_revolvente
# 29                                                 credit_reports__balance_due_ratio_max
# 236          credit_reports__balance_due_worst_delay_ratio_max_sin_limite_preestablecido
# 69                                credit_reports__age_std_credito_de_habilitacion_o_avio
# 264                                  credit_reports__cdc_inquiry_id_count_por_determinar
# 194                                 credit_reports__balance_due_worst_delay_max_hipoteca
# 265                                      credit_reports__cdc_inquiry_id_count_revolvente
# 1                                                            credit_reports__loans_count
# 39                                                 credit_reports__balance_due_ratio_std
# 35                                                 credit_reports__balance_due_ratio_std
# 317                                              credit_reports__debt_ratio_max_hipoteca
# 37                                                 credit_reports__balance_due_ratio_std
# 263                                     credit_reports__cdc_inquiry_id_count_pagos_fijos
# 126                      credit_reports__balance_due_ratio_max_sin_limite_preestablecido
# 23                                                 credit_reports__balance_due_ratio_max
# 172                                       credit_reports__balance_due_sum_por_determinar
# 258                                 credit_reports__business_type_nunique_por_determinar
# 199                           credit_reports__balance_due_worst_delay_max_por_determinar
# 34                                                 credit_reports__balance_due_ratio_std
# 38                                                 credit_reports__balance_due_ratio_std
# 9                                                         credit_reports__debt_ratio_max
# 91                                     credit_reports__balance_due_median_por_determinar
# 330                        credit_reports__max_credit_std_credito_de_habilitacion_o_avio
# 214                        credit_reports__balance_due_worst_delay_median_por_determinar
# 36                                                 credit_reports__balance_due_ratio_std
# 216                        credit_reports__balance_due_worst_delay_median_por_determinar
# 40                                     credit_reports__balance_due_worst_delay_ratio_max
# 180                            credit_reports__balance_due_sum_sin_limite_preestablecido
# 148                                 credit_reports__balance_due_ratio_std_por_determinar
# 197                           credit_reports__balance_due_worst_delay_max_por_determinar
# 327                     credit_reports__max_credit_median_credito_de_habilitacion_o_avio
# 147                   credit_reports__balance_due_ratio_median_sin_limite_preestablecido
# 299                                      credit_reports__current_balance_median_hipoteca
# 254                                       credit_reports__business_type_nunique_hipoteca
# 195                           credit_reports__balance_due_worst_delay_max_por_determinar
# 89                                     credit_reports__balance_due_median_por_determinar
# 95                                     credit_reports__balance_due_median_por_determinar
# 302                                credit_reports__current_balance_median_por_determinar
# 153                      credit_reports__balance_due_ratio_std_sin_limite_preestablecido
# 174                                       credit_reports__balance_due_sum_por_determinar
# 331                                           credit_reports__max_credit_std_pagos_fijos
# 336                         credit_reports__severity_delayed_payments_max_por_determinar
# 4                                                         credit_reports__max_credit_sum
# 300                                credit_reports__current_balance_median_por_determinar
# 56                                                    credit_reports__payment_amount_sum
# 118                                 credit_reports__balance_due_ratio_max_por_determinar
# 260                  credit_reports__cdc_inquiry_id_count_credito_de_habilitacion_o_avio
# 144                              credit_reports__balance_due_ratio_median_por_determinar
# 93                                     credit_reports__balance_due_median_por_determinar
# 261                                        credit_reports__cdc_inquiry_id_count_hipoteca
# 65                                             credit_reports__age_median_por_determinar
# 301                                credit_reports__current_balance_median_por_determinar
# 311                        credit_reports__current_balance_sum_sin_limite_preestablecido
# 262                                        credit_reports__cdc_inquiry_id_count_hipoteca
# 94                                     credit_reports__balance_due_median_por_determinar
# 143                                    credit_reports__balance_due_ratio_median_hipoteca
# 53                                 credit_reports__loans_with_at_least_one_delayed_count
# 7                                                        credit_reports__balance_due_sum
# 157                            credit_reports__balance_due_std_sin_limite_preestablecido
# 64                                             credit_reports__age_median_por_determinar
# 43                                     credit_reports__balance_due_worst_delay_ratio_max
# 198                           credit_reports__balance_due_worst_delay_max_por_determinar
# 277                                         credit_reports__credit_limit_median_hipoteca
# 142                                    credit_reports__balance_due_ratio_median_hipoteca
# 114                                       credit_reports__balance_due_ratio_max_hipoteca
# 45                                     credit_reports__balance_due_worst_delay_ratio_max
# 41                                     credit_reports__balance_due_worst_delay_ratio_max
# 10                                                        credit_reports__debt_ratio_max
# 90                                     credit_reports__balance_due_median_por_determinar
# 24                                                 credit_reports__balance_due_ratio_max
# 179                            credit_reports__balance_due_sum_sin_limite_preestablecido
# 196                           credit_reports__balance_due_worst_delay_max_por_determinar
# 173                                       credit_reports__balance_due_sum_por_determinar
# 217                        credit_reports__balance_due_worst_delay_median_por_determinar
# 279                           credit_reports__credit_limit_std_sin_limite_preestablecido
# 44                                     credit_reports__balance_due_worst_delay_ratio_max
# 88                                           credit_reports__balance_due_median_hipoteca
# 33                                                 credit_reports__balance_due_ratio_std
# 61                                                credit_reports__age_max_por_determinar
# 70                                credit_reports__age_std_credito_de_habilitacion_o_avio
# 21                                         credit_reports__severity_delayed_payments_max
# 115                                       credit_reports__balance_due_ratio_max_hipoteca
# 46                                     credit_reports__balance_due_worst_delay_ratio_max
# 42                                     credit_reports__balance_due_worst_delay_ratio_max
# 50                                     credit_reports__balance_due_worst_delay_ratio_std
# 60                                                credit_reports__age_max_por_determinar
# 215                        credit_reports__balance_due_worst_delay_median_por_determinar
# 68                                credit_reports__age_std_credito_de_habilitacion_o_avio
# 52                                     credit_reports__balance_due_worst_delay_ratio_std
# 48                                     credit_reports__balance_due_worst_delay_ratio_std
# 155                                       credit_reports__balance_due_std_por_determinar
# 276                                         credit_reports__credit_limit_median_hipoteca
# 251                           credit_reports__balance_due_worst_delay_std_por_determinar
# 49                                     credit_reports__balance_due_worst_delay_ratio_std
# 2                                                            credit_reports__loans_count
# 248                           credit_reports__balance_due_worst_delay_ratio_std_hipoteca
# 51                                     credit_reports__balance_due_worst_delay_ratio_std
# 47                                     credit_reports__balance_due_worst_delay_ratio_std
# 11                                                        credit_reports__debt_ratio_max
# 25                                                 credit_reports__balance_due_ratio_max
# 0                              previous_internal_apps__last_bnpl_app_to_application_days
# 32                                                 credit_reports__balance_due_ratio_std
# 309                                   credit_reports__current_balance_sum_por_determinar
# 329                                     credit_reports__max_credit_median_por_determinar
# 55                                      credit_reports__is_individual_responsibility_sum
# 62                                                credit_reports__age_max_por_determinar
# 176                                       credit_reports__balance_due_sum_por_determinar
# 19                                                   credit_reports__credit_type_nunique
# 200                               credit_reports__balance_due_worst_delay_max_revolvente
# 337              credit_reports__severity_delayed_payments_max_sin_limite_preestablecido
# 20                                                 credit_reports__business_type_nunique
# 256                                       credit_reports__business_type_nunique_hipoteca
# 67                                credit_reports__age_std_credito_de_habilitacion_o_avio
# 18                                                   credit_reports__credit_type_nunique
# 156                            credit_reports__balance_due_std_sin_limite_preestablecido
# 119                                 credit_reports__balance_due_ratio_max_por_determinar
# 3                                                            credit_reports__loans_count
# 259                      credit_reports__business_type_nunique_sin_limite_preestablecido
# 54                                      credit_reports__is_individual_responsibility_sum
# 59                                                credit_reports__age_max_por_determinar
# 289                                          credit_reports__credit_limit_sum_revolvente
# 22                                         credit_reports__severity_delayed_payments_std
# 291                                         credit_reports__credit_type_nunique_hipoteca
# 96                          credit_reports__balance_due_median_sin_limite_preestablecido
# 117                                 credit_reports__balance_due_ratio_max_por_determinar
# 231                     credit_reports__balance_due_worst_delay_ratio_max_por_determinar
# 288                                            credit_reports__credit_limit_sum_hipoteca
# 63                                                credit_reports__age_max_por_determinar
# 178                            credit_reports__balance_due_sum_sin_limite_preestablecido
# 257                                    credit_reports__business_type_nunique_pagos_fijos
# 290                           credit_reports__credit_limit_sum_sin_limite_preestablecido
# 66                                             credit_reports__age_median_por_determinar
# 278                           credit_reports__credit_limit_std_sin_limite_preestablecido
# 120                                 credit_reports__balance_due_ratio_max_por_determinar
# 232                     credit_reports__balance_due_worst_delay_ratio_max_por_determinar
# 252                credit_reports__balance_due_worst_delay_std_sin_limite_preestablecido
# 318                                           credit_reports__debt_ratio_max_pagos_fijos
# 253                 credit_reports__business_type_nunique_credito_de_habilitacion_o_avio
# 201                credit_reports__balance_due_worst_delay_max_sin_limite_preestablecido
# 230                        credit_reports__balance_due_worst_delay_ratio_max_pagos_fijos
#
#                                                                                Feature 2  \
# 228      credit_reports__severity_delayed_payments_median_credito_de_habilitacion_o_avio
# 246      credit_reports__severity_delayed_payments_median_credito_de_habilitacion_o_avio
# 245         credit_reports__severity_delayed_payments_max_credito_de_habilitacion_o_avio
# 227         credit_reports__severity_delayed_payments_max_credito_de_habilitacion_o_avio
# 283                     credit_reports__debt_ratio_median_credito_de_habilitacion_o_avio
# 103                   credit_reports__credit_limit_median_credito_de_habilitacion_o_avio
# 270                        credit_reports__debt_ratio_max_credito_de_habilitacion_o_avio
# 271                     credit_reports__debt_ratio_median_credito_de_habilitacion_o_avio
# 282                        credit_reports__debt_ratio_max_credito_de_habilitacion_o_avio
# 104                      credit_reports__credit_limit_sum_credito_de_habilitacion_o_avio
# 133                      credit_reports__credit_limit_sum_credito_de_habilitacion_o_avio
# 132                   credit_reports__credit_limit_median_credito_de_habilitacion_o_avio
# 130     credit_reports__balance_due_worst_delay_ratio_max_credito_de_habilitacion_o_avio
# 224                     credit_reports__debt_ratio_median_credito_de_habilitacion_o_avio
# 223                        credit_reports__debt_ratio_max_credito_de_habilitacion_o_avio
# 242                     credit_reports__debt_ratio_median_credito_de_habilitacion_o_avio
# 241                        credit_reports__debt_ratio_max_credito_de_habilitacion_o_avio
# 101     credit_reports__balance_due_worst_delay_ratio_max_credito_de_habilitacion_o_avio
# 102  credit_reports__balance_due_worst_delay_ratio_median_credito_de_habilitacion_o_avio
# 131  credit_reports__balance_due_worst_delay_ratio_median_credito_de_habilitacion_o_avio
# 226                    credit_reports__payment_amount_sum_credito_de_habilitacion_o_avio
# 182     credit_reports__balance_due_worst_delay_ratio_max_credito_de_habilitacion_o_avio
# 244                    credit_reports__payment_amount_sum_credito_de_habilitacion_o_avio
# 202     credit_reports__balance_due_worst_delay_ratio_max_credito_de_habilitacion_o_avio
# 183  credit_reports__balance_due_worst_delay_ratio_median_credito_de_habilitacion_o_avio
# 203  credit_reports__balance_due_worst_delay_ratio_median_credito_de_habilitacion_o_avio
# 219                   credit_reports__credit_limit_median_credito_de_habilitacion_o_avio
# 237                   credit_reports__credit_limit_median_credito_de_habilitacion_o_avio
# 238                      credit_reports__credit_limit_sum_credito_de_habilitacion_o_avio
# 220                      credit_reports__credit_limit_sum_credito_de_habilitacion_o_avio
# 274         credit_reports__severity_delayed_payments_max_credito_de_habilitacion_o_avio
# 287      credit_reports__severity_delayed_payments_median_credito_de_habilitacion_o_avio
# 286         credit_reports__severity_delayed_payments_max_credito_de_habilitacion_o_avio
# 275      credit_reports__severity_delayed_payments_median_credito_de_habilitacion_o_avio
# 139                    credit_reports__payment_amount_sum_credito_de_habilitacion_o_avio
# 321                    credit_reports__payment_amount_sum_credito_de_habilitacion_o_avio
# 314                    credit_reports__payment_amount_sum_credito_de_habilitacion_o_avio
# 110                    credit_reports__payment_amount_sum_credito_de_habilitacion_o_avio
# 168              credit_reports__has_delayed_payments_sum_credito_de_habilitacion_o_avio
# 84               credit_reports__has_delayed_payments_sum_credito_de_habilitacion_o_avio
# 295              credit_reports__has_delayed_payments_sum_credito_de_habilitacion_o_avio
# 305              credit_reports__has_delayed_payments_sum_credito_de_habilitacion_o_avio
# 76      credit_reports__balance_due_worst_delay_ratio_max_credito_de_habilitacion_o_avio
# 77   credit_reports__balance_due_worst_delay_ratio_median_credito_de_habilitacion_o_avio
# 160     credit_reports__balance_due_worst_delay_ratio_max_credito_de_habilitacion_o_avio
# 161  credit_reports__balance_due_worst_delay_ratio_median_credito_de_habilitacion_o_avio
# 210              credit_reports__has_delayed_payments_sum_credito_de_habilitacion_o_avio
# 221                credit_reports__current_balance_median_credito_de_habilitacion_o_avio
# 190              credit_reports__has_delayed_payments_sum_credito_de_habilitacion_o_avio
# 222                   credit_reports__current_balance_sum_credito_de_habilitacion_o_avio
# 239                credit_reports__current_balance_median_credito_de_habilitacion_o_avio
# 240                   credit_reports__current_balance_sum_credito_de_habilitacion_o_avio
# 208                        credit_reports__debt_ratio_max_credito_de_habilitacion_o_avio
# 313              credit_reports__has_delayed_payments_sum_credito_de_habilitacion_o_avio
# 99            credit_reports__balance_due_worst_delay_max_credito_de_habilitacion_o_avio
# 100        credit_reports__balance_due_worst_delay_median_credito_de_habilitacion_o_avio
# 138              credit_reports__has_delayed_payments_sum_credito_de_habilitacion_o_avio
# 128           credit_reports__balance_due_worst_delay_max_credito_de_habilitacion_o_avio
# 209                     credit_reports__debt_ratio_median_credito_de_habilitacion_o_avio
# 188                        credit_reports__debt_ratio_max_credito_de_habilitacion_o_avio
# 109              credit_reports__has_delayed_payments_sum_credito_de_habilitacion_o_avio
# 189                     credit_reports__debt_ratio_median_credito_de_habilitacion_o_avio
# 129        credit_reports__balance_due_worst_delay_median_credito_de_habilitacion_o_avio
# 320              credit_reports__has_delayed_payments_sum_credito_de_habilitacion_o_avio
# 322         credit_reports__severity_delayed_payments_max_credito_de_habilitacion_o_avio
# 140         credit_reports__severity_delayed_payments_max_credito_de_habilitacion_o_avio
# 141      credit_reports__severity_delayed_payments_median_credito_de_habilitacion_o_avio
# 315         credit_reports__severity_delayed_payments_max_credito_de_habilitacion_o_avio
# 316      credit_reports__severity_delayed_payments_median_credito_de_habilitacion_o_avio
# 191                    credit_reports__payment_amount_sum_credito_de_habilitacion_o_avio
# 324                    credit_reports__payment_amount_sum_credito_de_habilitacion_o_avio
# 325         credit_reports__severity_delayed_payments_max_credito_de_habilitacion_o_avio
# 326      credit_reports__severity_delayed_payments_median_credito_de_habilitacion_o_avio
# 112      credit_reports__severity_delayed_payments_median_credito_de_habilitacion_o_avio
# 111         credit_reports__severity_delayed_payments_max_credito_de_habilitacion_o_avio
# 211                    credit_reports__payment_amount_sum_credito_de_habilitacion_o_avio
# 323      credit_reports__severity_delayed_payments_median_credito_de_habilitacion_o_avio
# 97               credit_reports__balance_due_ratio_median_credito_de_habilitacion_o_avio
# 108                     credit_reports__debt_ratio_median_credito_de_habilitacion_o_avio
# 164                credit_reports__current_balance_median_credito_de_habilitacion_o_avio
# 165                   credit_reports__current_balance_sum_credito_de_habilitacion_o_avio
# 181        credit_reports__balance_due_worst_delay_median_credito_de_habilitacion_o_avio
# 107                        credit_reports__debt_ratio_max_credito_de_habilitacion_o_avio
# 137                     credit_reports__debt_ratio_median_credito_de_habilitacion_o_avio
# 81                    credit_reports__current_balance_sum_credito_de_habilitacion_o_avio
# 73                        credit_reports__balance_due_sum_credito_de_habilitacion_o_avio
# 292                   credit_reports__current_balance_sum_credito_de_habilitacion_o_avio
# 334      credit_reports__severity_delayed_payments_median_credito_de_habilitacion_o_avio
# 267                      credit_reports__credit_limit_sum_credito_de_habilitacion_o_avio
# 266           credit_reports__is_individual_responsibility_sum_sin_limite_preestablecido
# 218  credit_reports__balance_due_worst_delay_ratio_median_credito_de_habilitacion_o_avio
# 136                        credit_reports__debt_ratio_max_credito_de_habilitacion_o_avio
# 312                     credit_reports__debt_ratio_median_credito_de_habilitacion_o_avio
# 80                 credit_reports__current_balance_median_credito_de_habilitacion_o_avio
# 284              credit_reports__has_delayed_payments_sum_credito_de_habilitacion_o_avio
# 272              credit_reports__has_delayed_payments_sum_credito_de_habilitacion_o_avio
# 273                    credit_reports__payment_amount_sum_credito_de_habilitacion_o_avio
# 285                    credit_reports__payment_amount_sum_credito_de_habilitacion_o_avio
# 243              credit_reports__has_delayed_payments_sum_credito_de_habilitacion_o_avio
# 225              credit_reports__has_delayed_payments_sum_credito_de_habilitacion_o_avio
# 332         credit_reports__severity_delayed_payments_max_credito_de_habilitacion_o_avio
# 333      credit_reports__severity_delayed_payments_median_credito_de_habilitacion_o_avio
# 185                      credit_reports__credit_limit_sum_credito_de_habilitacion_o_avio
# 184                   credit_reports__credit_limit_median_credito_de_habilitacion_o_avio
# 162                   credit_reports__credit_limit_median_credito_de_habilitacion_o_avio
# 163                      credit_reports__credit_limit_sum_credito_de_habilitacion_o_avio
# 205                      credit_reports__credit_limit_sum_credito_de_habilitacion_o_avio
# 204                   credit_reports__credit_limit_median_credito_de_habilitacion_o_avio
# 79                       credit_reports__credit_limit_sum_credito_de_habilitacion_o_avio
# 78                    credit_reports__credit_limit_median_credito_de_habilitacion_o_avio
# 281                   credit_reports__current_balance_sum_credito_de_habilitacion_o_avio
# 269                   credit_reports__current_balance_sum_credito_de_habilitacion_o_avio
# 268                credit_reports__current_balance_median_credito_de_habilitacion_o_avio
# 280                credit_reports__current_balance_median_credito_de_habilitacion_o_avio
# 296                    credit_reports__payment_amount_sum_credito_de_habilitacion_o_avio
# 169                    credit_reports__payment_amount_sum_credito_de_habilitacion_o_avio
# 306                    credit_reports__payment_amount_sum_credito_de_habilitacion_o_avio
# 85                     credit_reports__payment_amount_sum_credito_de_habilitacion_o_avio
# 74            credit_reports__balance_due_worst_delay_max_credito_de_habilitacion_o_avio
# 159        credit_reports__balance_due_worst_delay_median_credito_de_habilitacion_o_avio
# 158           credit_reports__balance_due_worst_delay_max_credito_de_habilitacion_o_avio
# 75         credit_reports__balance_due_worst_delay_median_credito_de_habilitacion_o_avio
# 186                credit_reports__current_balance_median_credito_de_habilitacion_o_avio
# 207                   credit_reports__current_balance_sum_credito_de_habilitacion_o_avio
# 206                credit_reports__current_balance_median_credito_de_habilitacion_o_avio
# 187                   credit_reports__current_balance_sum_credito_de_habilitacion_o_avio
# 213      credit_reports__severity_delayed_payments_median_credito_de_habilitacion_o_avio
# 212         credit_reports__severity_delayed_payments_max_credito_de_habilitacion_o_avio
# 193      credit_reports__severity_delayed_payments_median_credito_de_habilitacion_o_avio
# 192         credit_reports__severity_delayed_payments_max_credito_de_habilitacion_o_avio
# 308      credit_reports__severity_delayed_payments_median_credito_de_habilitacion_o_avio
# 298      credit_reports__severity_delayed_payments_median_credito_de_habilitacion_o_avio
# 307         credit_reports__severity_delayed_payments_max_credito_de_habilitacion_o_avio
# 170         credit_reports__severity_delayed_payments_max_credito_de_habilitacion_o_avio
# 171      credit_reports__severity_delayed_payments_median_credito_de_habilitacion_o_avio
# 297         credit_reports__severity_delayed_payments_max_credito_de_habilitacion_o_avio
# 86          credit_reports__severity_delayed_payments_max_credito_de_habilitacion_o_avio
# 87       credit_reports__severity_delayed_payments_median_credito_de_habilitacion_o_avio
# 167                     credit_reports__debt_ratio_median_credito_de_habilitacion_o_avio
# 303                        credit_reports__debt_ratio_max_credito_de_habilitacion_o_avio
# 294                     credit_reports__debt_ratio_median_credito_de_habilitacion_o_avio
# 71                  credit_reports__balance_due_ratio_max_credito_de_habilitacion_o_avio
# 72               credit_reports__balance_due_ratio_median_credito_de_habilitacion_o_avio
# 293                        credit_reports__debt_ratio_max_credito_de_habilitacion_o_avio
# 82                         credit_reports__debt_ratio_max_credito_de_habilitacion_o_avio
# 83                      credit_reports__debt_ratio_median_credito_de_habilitacion_o_avio
# 304                     credit_reports__debt_ratio_median_credito_de_habilitacion_o_avio
# 166                        credit_reports__debt_ratio_max_credito_de_habilitacion_o_avio
# 134                credit_reports__current_balance_median_credito_de_habilitacion_o_avio
# 98                        credit_reports__balance_due_sum_credito_de_habilitacion_o_avio
# 105                credit_reports__current_balance_median_credito_de_habilitacion_o_avio
# 106                   credit_reports__current_balance_sum_credito_de_habilitacion_o_avio
# 135                   credit_reports__current_balance_sum_credito_de_habilitacion_o_avio
# 127                       credit_reports__balance_due_sum_credito_de_habilitacion_o_avio
# 152                                            credit_reports__debt_ratio_std_revolvente
# 124                                            credit_reports__debt_ratio_max_revolvente
# 16                                             credit_reports__debt_ratio_max_revolvente
# 12                                      credit_reports__balance_due_ratio_max_revolvente
# 145                      credit_reports__balance_due_worst_delay_ratio_median_revolvente
# 5                                             credit_reports__max_credit_sum_pagos_fijos
# 177                                    credit_reports__payment_amount_sum_por_determinar
# 57                             credit_reports__age_median_credito_de_habilitacion_o_avio
# 8                                                  credit_reports__balance_due_ratio_max
# 26                                      credit_reports__balance_due_ratio_max_revolvente
# 30                                             credit_reports__debt_ratio_max_revolvente
# 335                            credit_reports__severity_delayed_payments_median_hipoteca
# 92                                 credit_reports__current_balance_median_por_determinar
# 116                                    credit_reports__balance_due_ratio_std_pagos_fijos
# 150                         credit_reports__balance_due_worst_delay_ratio_std_revolvente
# 250                                            credit_reports__debt_ratio_std_revolvente
# 122                         credit_reports__balance_due_worst_delay_ratio_max_revolvente
# 234                                            credit_reports__debt_ratio_max_revolvente
# 14                          credit_reports__balance_due_worst_delay_ratio_max_revolvente
# 28                          credit_reports__balance_due_worst_delay_ratio_max_revolvente
# 154                           credit_reports__balance_due_worst_delay_std_por_determinar
# 146                                         credit_reports__debt_ratio_median_revolvente
# 247                                         credit_reports__debt_ratio_median_revolvente
# 255                                         credit_reports__credit_type_nunique_hipoteca
# 310                                    credit_reports__payment_amount_sum_por_determinar
# 328                        credit_reports__max_credit_sum_credito_de_habilitacion_o_avio
# 125                                            credit_reports__debt_ratio_std_revolvente
# ...
# 302                                    credit_reports__payment_amount_sum_por_determinar
# 153                             credit_reports__debt_ratio_std_sin_limite_preestablecido
# 174                                credit_reports__current_balance_median_por_determinar
# 331                                           credit_reports__max_credit_sum_pagos_fijos
# 336                      credit_reports__severity_delayed_payments_median_por_determinar
# 4                                             credit_reports__max_credit_std_pagos_fijos
# 300                                   credit_reports__current_balance_sum_por_determinar
# 56                                         credit_reports__open_loans_payment_amount_sum
# 118                     credit_reports__balance_due_worst_delay_ratio_max_por_determinar
# 260                   credit_reports__credit_type_nunique_credito_de_habilitacion_o_avio
# 144                  credit_reports__balance_due_worst_delay_ratio_median_por_determinar
# 93                                    credit_reports__current_balance_sum_por_determinar
# 261                                         credit_reports__credit_type_nunique_hipoteca
# 65                   credit_reports__balance_due_worst_delay_ratio_median_por_determinar
# 301                                     credit_reports__max_credit_median_por_determinar
# 311                         credit_reports__payment_amount_sum_sin_limite_preestablecido
# 262                            credit_reports__is_individual_responsibility_sum_hipoteca
# 94                                      credit_reports__max_credit_median_por_determinar
# 143                        credit_reports__balance_due_worst_delay_ratio_median_hipoteca
# 53                                  credit_reports__has_delayed_payments_sum_pagos_fijos
# 7                                             credit_reports__open_loans_balance_due_sum
# 157                        credit_reports__current_balance_std_sin_limite_preestablecido
# 64                               credit_reports__balance_due_ratio_median_por_determinar
# 43                          credit_reports__balance_due_worst_delay_ratio_max_revolvente
# 198                                     credit_reports__max_credit_median_por_determinar
# 277                                           credit_reports__max_credit_median_hipoteca
# 142                           credit_reports__balance_due_worst_delay_ratio_max_hipoteca
# 114                           credit_reports__balance_due_worst_delay_ratio_max_hipoteca
# 45                                             credit_reports__debt_ratio_max_revolvente
# 41                                      credit_reports__balance_due_ratio_max_revolvente
# 10                                     credit_reports__balance_due_worst_delay_ratio_max
# 90                            credit_reports__balance_due_worst_delay_max_por_determinar
# 24                                     credit_reports__balance_due_worst_delay_ratio_max
# 179                        credit_reports__current_balance_sum_sin_limite_preestablecido
# 196                                credit_reports__current_balance_median_por_determinar
# 173                        credit_reports__balance_due_worst_delay_median_por_determinar
# 217                                    credit_reports__payment_amount_sum_por_determinar
# 279                             credit_reports__max_credit_std_sin_limite_preestablecido
# 44                          credit_reports__balance_due_worst_delay_ratio_std_revolvente
# 88                                              credit_reports__balance_due_sum_hipoteca
# 33                                     credit_reports__balance_due_worst_delay_ratio_std
# 61                      credit_reports__balance_due_worst_delay_ratio_max_por_determinar
# 70                         credit_reports__max_credit_sum_credito_de_habilitacion_o_avio
# 21                             credit_reports__severity_delayed_payments_max_pagos_fijos
# 115                        credit_reports__balance_due_worst_delay_ratio_median_hipoteca
# 46                                             credit_reports__debt_ratio_std_revolvente
# 42                                      credit_reports__balance_due_ratio_std_revolvente
# 50                          credit_reports__balance_due_worst_delay_ratio_std_revolvente
# 60                                  credit_reports__balance_due_ratio_max_por_determinar
# 215                                   credit_reports__current_balance_sum_por_determinar
# 68                      credit_reports__max_credit_median_credito_de_habilitacion_o_avio
# 52                                             credit_reports__debt_ratio_std_revolvente
# 48                                      credit_reports__balance_due_ratio_std_revolvente
# 155                                   credit_reports__current_balance_std_por_determinar
# 276                                            credit_reports__credit_limit_sum_hipoteca
# 251                                   credit_reports__current_balance_std_por_determinar
# 49                          credit_reports__balance_due_worst_delay_ratio_max_revolvente
# 2                                       credit_reports__cdc_inquiry_id_count_pagos_fijos
# 248                                 credit_reports__balance_due_worst_delay_std_hipoteca
# 51                                             credit_reports__debt_ratio_max_revolvente
# 47                                      credit_reports__balance_due_ratio_max_revolvente
# 11                                     credit_reports__balance_due_worst_delay_ratio_std
# 25                                     credit_reports__balance_due_worst_delay_ratio_std
# 0                             previous_internal_apps__first_bnpl_app_to_application_days
# 32                                     credit_reports__balance_due_worst_delay_ratio_max
# 309                                     credit_reports__max_credit_median_por_determinar
# 329                                    credit_reports__payment_amount_sum_por_determinar
# 55                          credit_reports__is_individual_responsibility_sum_pagos_fijos
# 62                          credit_reports__severity_delayed_payments_max_por_determinar
# 176                                     credit_reports__max_credit_median_por_determinar
# 19                                       credit_reports__credit_type_nunique_pagos_fijos
# 200                               credit_reports__balance_due_worst_delay_std_revolvente
# 337           credit_reports__severity_delayed_payments_median_sin_limite_preestablecido
# 20                                     credit_reports__business_type_nunique_pagos_fijos
# 256                            credit_reports__is_individual_responsibility_sum_hipoteca
# 67                   credit_reports__cdc_inquiry_id_count_credito_de_habilitacion_o_avio
# 18                                                 credit_reports__business_type_nunique
# 156                credit_reports__balance_due_worst_delay_std_sin_limite_preestablecido
# 119                         credit_reports__severity_delayed_payments_max_por_determinar
# 3                           credit_reports__is_individual_responsibility_sum_pagos_fijos
# 259                        credit_reports__credit_type_nunique_sin_limite_preestablecido
# 54                                      credit_reports__cdc_inquiry_id_count_pagos_fijos
# 59                                             credit_reports__age_median_por_determinar
# 289                                            credit_reports__max_credit_sum_revolvente
# 22                             credit_reports__severity_delayed_payments_std_pagos_fijos
# 291                            credit_reports__is_individual_responsibility_sum_hipoteca
# 96              credit_reports__balance_due_worst_delay_median_sin_limite_preestablecido
# 117                              credit_reports__balance_due_ratio_median_por_determinar
# 231                  credit_reports__balance_due_worst_delay_ratio_median_por_determinar
# 288                                              credit_reports__max_credit_sum_hipoteca
# 63                       credit_reports__severity_delayed_payments_median_por_determinar
# 178                credit_reports__balance_due_worst_delay_max_sin_limite_preestablecido
# 257                                      credit_reports__credit_type_nunique_pagos_fijos
# 290                             credit_reports__max_credit_sum_sin_limite_preestablecido
# 66                       credit_reports__severity_delayed_payments_median_por_determinar
# 278                           credit_reports__credit_limit_sum_sin_limite_preestablecido
# 120                      credit_reports__severity_delayed_payments_median_por_determinar
# 232                         credit_reports__severity_delayed_payments_max_por_determinar
# 252                        credit_reports__current_balance_std_sin_limite_preestablecido
# 318                                           credit_reports__debt_ratio_std_pagos_fijos
# 253                   credit_reports__credit_type_nunique_credito_de_habilitacion_o_avio
# 201                credit_reports__balance_due_worst_delay_std_sin_limite_preestablecido
# 230                        credit_reports__balance_due_worst_delay_ratio_std_pagos_fijos
#
#      Correlation
# 228     1.000000
# 246     1.000000
# 245     1.000000
# 227     1.000000
# 283     1.000000
# 103     1.000000
# 270     1.000000
# 271     1.000000
# 282     1.000000
# 104     1.000000
# 133     1.000000
# 132     1.000000
# 130     1.000000
# 224     1.000000
# 223     1.000000
# 242     1.000000
# 241     1.000000
# 101     1.000000
# 102     1.000000
# 131     1.000000
# 226     1.000000
# 182     1.000000
# 244     1.000000
# 202     1.000000
# 183     1.000000
# 203     1.000000
# 219     1.000000
# 237     1.000000
# 238     1.000000
# 220     1.000000
# 274     1.000000
# 287     1.000000
# 286     1.000000
# 275     1.000000
# 139     1.000000
# 321     1.000000
# 314     1.000000
# 110     1.000000
# 168     1.000000
# 84      1.000000
# 295     1.000000
# 305     1.000000
# 76      1.000000
# 77      1.000000
# 160     1.000000
# 161     1.000000
# 210     1.000000
# 221     1.000000
# 190     1.000000
# 222     1.000000
# 239     1.000000
# 240     1.000000
# 208     1.000000
# 313     1.000000
# 99      1.000000
# 100     1.000000
# 138     1.000000
# 128     1.000000
# 209     1.000000
# 188     1.000000
# 109     1.000000
# 189     1.000000
# 129     1.000000
# 320     1.000000
# 322     1.000000
# 140     1.000000
# 141     1.000000
# 315     1.000000
# 316     1.000000
# 191     1.000000
# 324     1.000000
# 325     1.000000
# 326     1.000000
# 112     1.000000
# 111     1.000000
# 211     1.000000
# 323     1.000000
# 97      1.000000
# 108     1.000000
# 164     1.000000
# 165     1.000000
# 181     1.000000
# 107     1.000000
# 137     1.000000
# 81      1.000000
# 73      1.000000
# 292     1.000000
# 334     1.000000
# 267     1.000000
# 266     1.000000
# 218     1.000000
# 136     1.000000
# 312     1.000000
# 80      1.000000
# 284     1.000000
# 272     1.000000
# 273     1.000000
# 285     1.000000
# 243     1.000000
# 225     1.000000
# 332     1.000000
# 333     1.000000
# 185     1.000000
# 184     1.000000
# 162     1.000000
# 163     1.000000
# 205     1.000000
# 204     1.000000
# 79      1.000000
# 78      1.000000
# 281     1.000000
# 269     1.000000
# 268     1.000000
# 280     1.000000
# 296     1.000000
# 169     1.000000
# 306     1.000000
# 85      1.000000
# 74      1.000000
# 159     1.000000
# 158     1.000000
# 75      1.000000
# 186     1.000000
# 207     1.000000
# 206     1.000000
# 187     1.000000
# 213     1.000000
# 212     1.000000
# 193     1.000000
# 192     1.000000
# 308     1.000000
# 298     1.000000
# 307     1.000000
# 170     1.000000
# 171     1.000000
# 297     1.000000
# 86      1.000000
# 87      1.000000
# 167     1.000000
# 303     1.000000
# 294     1.000000
# 71      1.000000
# 72      1.000000
# 293     1.000000
# 82      1.000000
# 83      1.000000
# 304     1.000000
# 166     1.000000
# 134     1.000000
# 98      1.000000
# 105     1.000000
# 106     1.000000
# 135     1.000000
# 127     1.000000
# 152     1.000000
# 124     0.999998
# 16      0.999997
# 12      0.999996
# 145     0.999941
# 5       0.999730
# 177     0.999696
# 57      0.999528
# 8       0.999486
# 26      0.999486
# 30      0.999484
# 335     0.999432
# 92      0.999131
# 116     0.998806
# 150     0.998745
# 250     0.998744
# 122     0.998327
# 234     0.998325
# 14      0.998322
# 28      0.997812
# 154     0.997812
# 146     0.997549
# 247     0.997501
# 255     0.996972
# 310     0.996316
# 328     0.996048
# 125     0.995381
# 121     0.995381
# 319     0.995380
# 151     0.995379
# 17      0.995376
# 13      0.995376
# 233     0.995364
# 31      0.994868
# 27      0.994868
# 229     0.994309
# 175     0.994223
# 123     0.994132
# 249     0.994130
# 15      0.994127
# 58      0.994085
# 6       0.994064
# 113     0.993722
# 235     0.993715
# 149     0.993715
# 29      0.993619
# 236     0.993593
# 69      0.992819
# 264     0.992499
# 194     0.991285
# 265     0.990153
# 1       0.990034
# 39      0.989752
# 35      0.989751
# 317     0.989307
# 37      0.988508
# 263     0.987898
# 126     0.985018
# 23      0.984621
# 172     0.983380
# 258     0.983216
# 199     0.983079
# 34      0.982886
# 38      0.982884
# 9       0.982884
# 91      0.982276
# 330     0.981737
# 214     0.981420
# 36      0.981239
# 216     0.980748
# 40      0.979820
# 180     0.979660
# 148     0.978205
# 197     0.977685
# 327     0.976271
# 147     0.975567
# 299     0.974987
# 254     0.974855
# 195     0.972551
# 89      0.971651
# 95      0.971395
# 302     0.971206
# 153     0.971025
# 174     0.970796
# 331     0.969958
# 336     0.969690
# 4       0.969509
# 300     0.968112
# 56      0.967161
# 118     0.966925
# 260     0.966746
# 144     0.966724
# 93      0.966089
# 261     0.965536
# 65      0.965331
# 301     0.964751
# 311     0.964014
# 262     0.963934
# 94      0.962768
# 143     0.961696
# 53      0.960984
# 7       0.960690
# 157     0.960596
# 64      0.959359
# 43      0.957487
# 198     0.956726
# 277     0.956107
# 142     0.956099
# 114     0.956061
# 45      0.955893
# 41      0.955893
# 10      0.955891
# 90      0.955514
# 24      0.955398
# 179     0.954806
# 196     0.954671
# 173     0.954412
# 217     0.954159
# 279     0.953572
# 44      0.953041
# 88      0.952607
# 33      0.952253
# 61      0.952202
# 70      0.952151
# 21      0.952029
# 115     0.951808
# 46      0.951470
# 42      0.951468
# 50      0.949451
# 60      0.949443
# 215     0.948935
# 68      0.947320
# 52      0.947146
# 48      0.947143
# 155     0.945183
# 276     0.944793
# 251     0.943131
# 49      0.943041
# 2       0.942844
# 248     0.940653
# 51      0.940580
# 47      0.940580
# 11      0.940578
# 25      0.940092
# 0       0.939842
# 32      0.939505
# 309     0.939350
# 329     0.939081
# 55      0.938206
# 62      0.938109
# 176     0.937862
# 19      0.937560
# 200     0.937539
# 337     0.937288
# 20      0.935551
# 256     0.933962
# 67      0.933741
# 18      0.933437
# 156     0.933318
# 119     0.932067
# 3       0.930979
# 259     0.929602
# 54      0.929163
# 59      0.928679
# 289     0.928182
# 22      0.927407
# 291     0.923650
# 96      0.922398
# 117     0.920347
# 231     0.920080
# 288     0.916671
# 63      0.913579
# 178     0.913187
# 257     0.909602
# 290     0.907050
# 66      0.905581
# 278     0.905550
# 120     0.904694
# 232     0.904545
# 252     0.904471
# 318     0.904108
# 253     0.903661
# 201     0.902170
# 230     0.900260

# %%
exclude_features = [
    "credit_reports__balance_due_ratio_max",
    "credit_reports__open_loans_current_balance_sum",
    "credit_reports__is_individual_responsibility_sum",
    "credit_reports__balance_due_ratio_std",
    "credit_reports__balance_due_worst_delay_ratio_std",
    "credit_reports__open_loans_payment_amount_sum",
    "credit_reports__open_loans_balance_due_sum",
    "credit_reports__balance_due_worst_delay_ratio_max",
    "credit_reports__balance_due_worst_delay_ratio_std",
    "credit_reports__balance_due_worst_delay_ratio_max",
    "credit_reports__business_type_nunique",

    'credit_reports__age_median_credito_de_habilitacion_o_avio',
    'credit_reports__age_median_hipoteca',
    'credit_reports__age_median_por_determinar',
    'credit_reports__balance_due_ratio_max',
    'credit_reports__balance_due_ratio_max_credito_de_habilitacion_o_avio',
    'credit_reports__balance_due_ratio_max_por_determinar',
    'credit_reports__balance_due_ratio_max_revolvente',
    'credit_reports__balance_due_ratio_median_credito_de_habilitacion_o_avio',
    'credit_reports__balance_due_ratio_median_hipoteca',
    'credit_reports__balance_due_ratio_median_por_determinar',
    'credit_reports__balance_due_ratio_std_pagos_fijos',
    'credit_reports__balance_due_ratio_std_revolvente',
    'credit_reports__balance_due_sum_credito_de_habilitacion_o_avio',
    'credit_reports__balance_due_sum_hipoteca',
    'credit_reports__balance_due_sum_por_determinar',
    'credit_reports__balance_due_worst_delay_max_credito_de_habilitacion_o_avio',
    'credit_reports__balance_due_worst_delay_max_por_determinar',
    'credit_reports__balance_due_worst_delay_max_sin_limite_preestablecido',
    'credit_reports__balance_due_worst_delay_median_credito_de_habilitacion_o_avio',
    'credit_reports__balance_due_worst_delay_median_hipoteca',
    'credit_reports__balance_due_worst_delay_median_por_determinar',
    'credit_reports__balance_due_worst_delay_median_sin_limite_preestablecido',
    'credit_reports__balance_due_worst_delay_ratio_max_credito_de_habilitacion_o_avio',
    'credit_reports__balance_due_worst_delay_ratio_max_hipoteca',
    'credit_reports__balance_due_worst_delay_ratio_max_por_determinar',
    'credit_reports__balance_due_worst_delay_ratio_max_revolvente',
    'credit_reports__balance_due_worst_delay_ratio_median_credito_de_habilitacion_o_avio',
    'credit_reports__balance_due_worst_delay_ratio_median_hipoteca',
    'credit_reports__balance_due_worst_delay_ratio_median_por_determinar',
    'credit_reports__balance_due_worst_delay_ratio_median_revolvente',
    'credit_reports__balance_due_worst_delay_ratio_std_pagos_fijos',
    'credit_reports__balance_due_worst_delay_ratio_std_por_determinar',
    'credit_reports__balance_due_worst_delay_ratio_std_revolvente',
    'credit_reports__balance_due_worst_delay_ratio_std_sin_limite_preestablecido',
    'credit_reports__balance_due_worst_delay_std_hipoteca',
    'credit_reports__balance_due_worst_delay_std_por_determinar',
    'credit_reports__balance_due_worst_delay_std_revolvente',
    'credit_reports__balance_due_worst_delay_std_sin_limite_preestablecido',
    'credit_reports__business_type_nunique_pagos_fijos',
    'credit_reports__cdc_inquiry_id_count_credito_de_habilitacion_o_avio',
    'credit_reports__cdc_inquiry_id_count_hipoteca',
    'credit_reports__cdc_inquiry_id_count_pagos_fijos',
    'credit_reports__credit_limit_median_credito_de_habilitacion_o_avio',
    'credit_reports__credit_limit_sum_credito_de_habilitacion_o_avio',
    'credit_reports__credit_limit_sum_hipoteca',
    'credit_reports__credit_limit_sum_sin_limite_preestablecido',
    'credit_reports__credit_type_nunique_credito_de_habilitacion_o_avio',
    'credit_reports__credit_type_nunique_hipoteca',
    'credit_reports__credit_type_nunique_pagos_fijos',
    'credit_reports__credit_type_nunique_por_determinar',
    'credit_reports__credit_type_nunique_sin_limite_preestablecido',
    'credit_reports__current_balance_median_credito_de_habilitacion_o_avio',
    'credit_reports__current_balance_median_por_determinar',
    'credit_reports__current_balance_std_por_determinar',
    'credit_reports__current_balance_std_sin_limite_preestablecido',
    'credit_reports__current_balance_sum_credito_de_habilitacion_o_avio',
    'credit_reports__current_balance_sum_hipoteca',
    'credit_reports__current_balance_sum_por_determinar',
    'credit_reports__current_balance_sum_sin_limite_preestablecido',
    'credit_reports__debt_ratio_max_credito_de_habilitacion_o_avio',
    'credit_reports__debt_ratio_max_revolvente',
    'credit_reports__debt_ratio_max_sin_limite_preestablecido',
    'credit_reports__debt_ratio_median_credito_de_habilitacion_o_avio',
    'credit_reports__debt_ratio_median_hipoteca',
    'credit_reports__debt_ratio_median_revolvente',
    'credit_reports__debt_ratio_median_sin_limite_preestablecido',
    'credit_reports__debt_ratio_std_pagos_fijos',
    'credit_reports__debt_ratio_std_revolvente',
    'credit_reports__debt_ratio_std_sin_limite_preestablecido',
    'credit_reports__has_delayed_payments_sum_credito_de_habilitacion_o_avio',
    'credit_reports__has_delayed_payments_sum_pagos_fijos',
    'credit_reports__is_individual_responsibility_sum_hipoteca',
    'credit_reports__is_individual_responsibility_sum_pagos_fijos',
    'credit_reports__is_individual_responsibility_sum_por_determinar',
    'credit_reports__is_individual_responsibility_sum_revolvente',
    'credit_reports__is_individual_responsibility_sum_sin_limite_preestablecido',
    'credit_reports__max_credit_median_credito_de_habilitacion_o_avio',
    'credit_reports__max_credit_median_hipoteca',
    'credit_reports__max_credit_median_por_determinar',
    'credit_reports__max_credit_std_credito_de_habilitacion_o_avio',
    'credit_reports__max_credit_std_pagos_fijos',
    'credit_reports__max_credit_std_sin_limite_preestablecido',
    'credit_reports__max_credit_sum_credito_de_habilitacion_o_avio',
    'credit_reports__max_credit_sum_hipoteca',
    'credit_reports__max_credit_sum_pagos_fijos',
    'credit_reports__max_credit_sum_revolvente',
    'credit_reports__max_credit_sum_sin_limite_preestablecido',
    'credit_reports__payment_amount_sum_credito_de_habilitacion_o_avio',
    'credit_reports__payment_amount_sum_por_determinar',
    'credit_reports__payment_amount_sum_sin_limite_preestablecido',
    'credit_reports__severity_delayed_payments_max_credito_de_habilitacion_o_avio',
    'credit_reports__severity_delayed_payments_max_pagos_fijos',
    'credit_reports__severity_delayed_payments_max_por_determinar',
    'credit_reports__severity_delayed_payments_median_credito_de_habilitacion_o_avio',
    'credit_reports__severity_delayed_payments_median_hipoteca',
    'credit_reports__severity_delayed_payments_median_por_determinar',
    'credit_reports__severity_delayed_payments_median_sin_limite_preestablecido',
    'credit_reports__severity_delayed_payments_std_pagos_fijos',
]
len(exclude_features)
# Out:
# 109

# %%
result_list = set(features) - set(exclude_features)
result_list = list(result_list)
result_list.sort()
result_list
# Out:
# ['credit_reports__age_max',
#  'credit_reports__age_max_credito_de_habilitacion_o_avio',
#  'credit_reports__age_max_hipoteca',
#  'credit_reports__age_max_pagos_fijos',
#  'credit_reports__age_max_por_determinar',
#  'credit_reports__age_max_revolvente',
#  'credit_reports__age_max_sin_limite_preestablecido',
#  'credit_reports__age_median_pagos_fijos',
#  'credit_reports__age_median_revolvente',
#  'credit_reports__age_median_sin_limite_preestablecido',
#  'credit_reports__age_min',
#  'credit_reports__age_std_credito_de_habilitacion_o_avio',
#  'credit_reports__age_std_hipoteca',
#  'credit_reports__age_std_pagos_fijos',
#  'credit_reports__age_std_por_determinar',
#  'credit_reports__age_std_revolvente',
#  'credit_reports__age_std_sin_limite_preestablecido',
#  'credit_reports__balance_due_median_credito_de_habilitacion_o_avio',
#  'credit_reports__balance_due_median_hipoteca',
#  'credit_reports__balance_due_median_pagos_fijos',
#  'credit_reports__balance_due_median_por_determinar',
#  'credit_reports__balance_due_median_revolvente',
#  'credit_reports__balance_due_median_sin_limite_preestablecido',
#  'credit_reports__balance_due_ratio_max_hipoteca',
#  'credit_reports__balance_due_ratio_max_pagos_fijos',
#  'credit_reports__balance_due_ratio_max_sin_limite_preestablecido',
#  'credit_reports__balance_due_ratio_median',
#  'credit_reports__balance_due_ratio_median_pagos_fijos',
#  'credit_reports__balance_due_ratio_median_revolvente',
#  'credit_reports__balance_due_ratio_median_sin_limite_preestablecido',
#  'credit_reports__balance_due_ratio_std_credito_de_habilitacion_o_avio',
#  'credit_reports__balance_due_ratio_std_hipoteca',
#  'credit_reports__balance_due_ratio_std_por_determinar',
#  'credit_reports__balance_due_ratio_std_sin_limite_preestablecido',
#  'credit_reports__balance_due_std_credito_de_habilitacion_o_avio',
#  'credit_reports__balance_due_std_hipoteca',
#  'credit_reports__balance_due_std_pagos_fijos',
#  'credit_reports__balance_due_std_por_determinar',
#  'credit_reports__balance_due_std_revolvente',
#  'credit_reports__balance_due_std_sin_limite_preestablecido',
#  'credit_reports__balance_due_sum',
#  'credit_reports__balance_due_sum_pagos_fijos',
#  'credit_reports__balance_due_sum_revolvente',
#  'credit_reports__balance_due_sum_sin_limite_preestablecido',
#  'credit_reports__balance_due_worst_delay_max',
#  'credit_reports__balance_due_worst_delay_max_hipoteca',
#  'credit_reports__balance_due_worst_delay_max_pagos_fijos',
#  'credit_reports__balance_due_worst_delay_max_revolvente',
#  'credit_reports__balance_due_worst_delay_median_pagos_fijos',
#  'credit_reports__balance_due_worst_delay_median_revolvente',
#  'credit_reports__balance_due_worst_delay_ratio_max_pagos_fijos',
#  'credit_reports__balance_due_worst_delay_ratio_max_sin_limite_preestablecido',
#  'credit_reports__balance_due_worst_delay_ratio_median',
#  'credit_reports__balance_due_worst_delay_ratio_median_pagos_fijos',
#  'credit_reports__balance_due_worst_delay_ratio_median_sin_limite_preestablecido',
#  'credit_reports__balance_due_worst_delay_ratio_std_credito_de_habilitacion_o_avio',
#  'credit_reports__balance_due_worst_delay_ratio_std_hipoteca',
#  'credit_reports__balance_due_worst_delay_std_credito_de_habilitacion_o_avio',
#  'credit_reports__balance_due_worst_delay_std_pagos_fijos',
#  'credit_reports__business_type_nunique_credito_de_habilitacion_o_avio',
#  'credit_reports__business_type_nunique_hipoteca',
#  'credit_reports__business_type_nunique_por_determinar',
#  'credit_reports__business_type_nunique_revolvente',
#  'credit_reports__business_type_nunique_sin_limite_preestablecido',
#  'credit_reports__cdc_inquiry_id_count_por_determinar',
#  'credit_reports__cdc_inquiry_id_count_revolvente',
#  'credit_reports__cdc_inquiry_id_count_sin_limite_preestablecido',
#  'credit_reports__credit_limit_median_hipoteca',
#  'credit_reports__credit_limit_median_pagos_fijos',
#  'credit_reports__credit_limit_median_por_determinar',
#  'credit_reports__credit_limit_median_revolvente',
#  'credit_reports__credit_limit_median_sin_limite_preestablecido',
#  'credit_reports__credit_limit_std_credito_de_habilitacion_o_avio',
#  'credit_reports__credit_limit_std_hipoteca',
#  'credit_reports__credit_limit_std_pagos_fijos',
#  'credit_reports__credit_limit_std_por_determinar',
#  'credit_reports__credit_limit_std_revolvente',
#  'credit_reports__credit_limit_std_sin_limite_preestablecido',
#  'credit_reports__credit_limit_sum',
#  'credit_reports__credit_limit_sum_pagos_fijos',
#  'credit_reports__credit_limit_sum_por_determinar',
#  'credit_reports__credit_limit_sum_revolvente',
#  'credit_reports__credit_type_nunique',
#  'credit_reports__credit_type_nunique_revolvente',
#  'credit_reports__current_balance_median_hipoteca',
#  'credit_reports__current_balance_median_pagos_fijos',
#  'credit_reports__current_balance_median_revolvente',
#  'credit_reports__current_balance_median_sin_limite_preestablecido',
#  'credit_reports__current_balance_std_credito_de_habilitacion_o_avio',
#  'credit_reports__current_balance_std_hipoteca',
#  'credit_reports__current_balance_std_pagos_fijos',
#  'credit_reports__current_balance_std_revolvente',
#  'credit_reports__current_balance_sum',
#  'credit_reports__current_balance_sum_pagos_fijos',
#  'credit_reports__current_balance_sum_revolvente',
#  'credit_reports__debt_due_ratio',
#  'credit_reports__debt_ratio',
#  'credit_reports__debt_ratio_max',
#  'credit_reports__debt_ratio_max_hipoteca',
#  'credit_reports__debt_ratio_max_pagos_fijos',
#  'credit_reports__debt_ratio_max_por_determinar',
#  'credit_reports__debt_ratio_median',
#  'credit_reports__debt_ratio_median_pagos_fijos',
#  'credit_reports__debt_ratio_median_por_determinar',
#  'credit_reports__debt_ratio_std_credito_de_habilitacion_o_avio',
#  'credit_reports__debt_ratio_std_hipoteca',
#  'credit_reports__debt_ratio_std_por_determinar',
#  'credit_reports__has_delayed_payments_sum_hipoteca',
#  'credit_reports__has_delayed_payments_sum_por_determinar',
#  'credit_reports__has_delayed_payments_sum_revolvente',
#  'credit_reports__has_delayed_payments_sum_sin_limite_preestablecido',
#  'credit_reports__is_individual_responsibility_sum_credito_de_habilitacion_o_avio',
#  'credit_reports__loans_count',
#  'credit_reports__loans_with_at_least_one_delayed_count',
#  'credit_reports__loans_with_at_least_one_delayed_ratio',
#  'credit_reports__max_credit_median_pagos_fijos',
#  'credit_reports__max_credit_median_revolvente',
#  'credit_reports__max_credit_median_sin_limite_preestablecido',
#  'credit_reports__max_credit_std_hipoteca',
#  'credit_reports__max_credit_std_por_determinar',
#  'credit_reports__max_credit_std_revolvente',
#  'credit_reports__max_credit_sum',
#  'credit_reports__max_credit_sum_por_determinar',
#  'credit_reports__open_loans_count',
#  'credit_reports__open_loans_credit_limit_sum',
#  'credit_reports__open_loans_max_credit_sum',
#  'credit_reports__opening_loans_ratio',
#  'credit_reports__payment_amount_sum',
#  'credit_reports__payment_amount_sum_hipoteca',
#  'credit_reports__payment_amount_sum_pagos_fijos',
#  'credit_reports__payment_amount_sum_revolvente',
#  'credit_reports__severity_delayed_payments_max',
#  'credit_reports__severity_delayed_payments_max_hipoteca',
#  'credit_reports__severity_delayed_payments_max_revolvente',
#  'credit_reports__severity_delayed_payments_max_sin_limite_preestablecido',
#  'credit_reports__severity_delayed_payments_median',
#  'credit_reports__severity_delayed_payments_median_pagos_fijos',
#  'credit_reports__severity_delayed_payments_median_revolvente',
#  'credit_reports__severity_delayed_payments_std',
#  'credit_reports__severity_delayed_payments_std_credito_de_habilitacion_o_avio',
#  'credit_reports__severity_delayed_payments_std_hipoteca',
#  'credit_reports__severity_delayed_payments_std_por_determinar',
#  'credit_reports__severity_delayed_payments_std_revolvente',
#  'credit_reports__severity_delayed_payments_std_sin_limite_preestablecido',
#  'previous_internal_apps__account_to_application_days',
#  'previous_internal_apps__first_bnpl_app_to_application_days',
#  'previous_internal_apps__last_bnpl_app_to_application_days',
#  'previous_internal_apps__n_bnpl_approved_apps',
#  'previous_internal_apps__n_bnpl_apps',
#  'previous_internal_apps__n_inquiries_l3m',
#  'previous_internal_apps__n_inquiries_l6m',
#  'previous_internal_apps__n_sf_apps',
#  'previous_internal_apps__ratio_bnpl_approved']
